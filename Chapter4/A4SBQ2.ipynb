# %%
import csv
from itertools import combinations, chain
from collections import defaultdict

def load_transactions(file_path):
    """
    Load the groceries dataset, expecting one “basket” per line (items separated by commas),
    or possibly a “basket” representation. Adjust as per actual file format.
    Returns a list of transactions (each transaction is a set of items).
    """
    transactions = []
    with open(file_path, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        for row in reader:
            # If there are empty entries, filter them out
            items = [item.strip() for item in row if item and item.strip() != '']
            if len(items) > 0:
                transactions.append(set(items))
    return transactions

def get_frequent_itemsets(transactions, min_support):
    """
    Run Apriori to find all frequent itemsets with support >= min_support.
    Returns dict: frequent_itemsets[k] = dict mapping itemset (frozenset) → support (float)
    Also returns a dict all_frequent mapping every frequent itemset to its support.
    """
    num_trans = len(transactions)
    # 1. Generate L1 (frequent 1-itemsets)
    item_counts = defaultdict(int)
    for trans in transactions:
        for item in trans:
            item_counts[frozenset([item])] += 1
    L1 = {}
    for itemset, count in item_counts.items():
        sup = count / num_trans
        if sup >= min_support:
            L1[itemset] = sup

    frequent_itemsets = dict()
    frequent_itemsets[1] = L1
    all_frequent = dict(L1)  # include 1-itemsets

    k = 2
    while True:
        prev_L = frequent_itemsets.get(k-1, {})
        if not prev_L:
            break
        # Generate candidates Ck from (k-1)-itemsets
        candidates = set()
        prev_itemsets = list(prev_L.keys())
        len_prev = len(prev_itemsets)
        for i in range(len_prev):
            for j in range(i+1, len_prev):
                s1 = prev_itemsets[i]
                s2 = prev_itemsets[j]
                # join step: if they share k-2 items, union them
                if len(s1.union(s2)) == k:
                    candidates.add(s1.union(s2))
        # Prune candidates: all (k-1)-subsets of candidate must be frequent
        candidates_pruned = set()
        for cand in candidates:
            all_sub_ok = True
            for subset in combinations(cand, k-1):
                if frozenset(subset) not in prev_L:
                    all_sub_ok = False
                    break
            if all_sub_ok:
                candidates_pruned.add(cand)

        # Count support of candidates by scanning transactions
        cand_count = defaultdict(int)
        for trans in transactions:
            for cand in candidates_pruned:
                if cand.issubset(trans):
                    cand_count[frozenset(cand)] += 1
        Lk = {}
        for cand, count in cand_count.items():
            sup = count / num_trans
            if sup >= min_support:
                Lk[cand] = sup
        if not Lk:
            break
        frequent_itemsets[k] = Lk
        all_frequent.update(Lk)
        k += 1

    return frequent_itemsets, all_frequent

def generate_association_rules(all_frequent, min_confidence, min_lift, min_length, transactions):
    """
    From all frequent itemsets, generate possible association rules X -> Y
    (for all splits: X ∪ Y = itemset, X ∩ Y = ∅), and compute support, confidence, lift.
    Returns a list of rules: each rule is a tuple (X, Y, support, confidence, lift).
    """
    num_trans = len(transactions)
    rules = []
    # For each frequent itemset of size ≥ 2
    for itemset, supp_itemset in all_frequent.items():
        if len(itemset) < 2:
            continue
        # for every possible non-empty proper subset X
        # Y = itemset \ X
        # We only consider rules where |X| ≥ 1 and |Y| ≥ 1, and |X| + |Y| = len(itemset)
        subsets = chain.from_iterable(combinations(itemset, r) for r in range(1, len(itemset)))
        for subset in subsets:
            X = frozenset(subset)
            Y = itemset - X
            if not Y:
                continue
            # support of X
            sup_X = all_frequent.get(X, 0)
            # support of Y
            sup_Y = all_frequent.get(Y, 0)
            if sup_X <= 0:
                continue
            # confidence = support(X ∪ Y) / support(X)
            conf = supp_itemset / sup_X
            # lift = confidence / support(Y)
            if sup_Y <= 0:
                continue
            lift = conf / sup_Y
            # filter by thresholds
            if conf >= min_confidence and lift >= min_lift and (len(X) + len(Y)) >= min_length:
                rules.append((X, Y, supp_itemset, conf, lift))
    return rules

def print_rules(rules):
    """
    Print rules with their support, confidence, lift in a readable form.
    """
    # Sort rules by e.g. descending lift or confidence
    rules_sorted = sorted(rules, key=lambda x: (x[4], x[3]), reverse=True)
    print(f"{'Rule':40s}  {'Support':>8s}  {'Confidence':>10s}  {'Lift':>8s}")
    print("-" * 70)
    for (X, Y, supp, conf, lift) in rules_sorted:
        rule_str = f"{set(X)} => {set(Y)}"
        print(f"{rule_str:40s}  {supp:8.4f}  {conf:10.4f}  {lift:8.4f}")

def main():
    # Parameters
    min_support = 0.0040
    min_confidence = 0.2
    min_lift = 3.0
    min_length = 2

    # Path to the groceries dataset (adjust as needed)
    file_path = "groceries.csv"
    print("Loading transactions …")
    transactions = load_transactions(file_path)
    print(f"Total transactions loaded: {len(transactions)}")

    print("Running Apriori to find frequent itemsets …")
    frequent_itemsets, all_frequent = get_frequent_itemsets(transactions, min_support)
    total_freq = sum(len(v) for v in frequent_itemsets.values())
    print(f"Found {total_freq} frequent itemsets")

    print("Generating association rules …")
    rules = generate_association_rules(all_frequent, min_confidence, min_lift, min_length, transactions)
    print(f"Number of rules found: {len(rules)}")

    print("\n== Rules meeting thresholds ==")
    print_rules(rules)

if __name__ == "__main__":
    main()
# Out:
# Loading transactions …
# Total transactions loaded: 9835
# Running Apriori to find frequent itemsets …
# Found 1398 frequent itemsets
# Generating association rules …
# Number of rules found: 153
#
# == Rules meeting thresholds ==
# Rule                                       Support  Confidence      Lift
# ----------------------------------------------------------------------
# {'flour'} => {'sugar'}                      0.0050      0.2865    8.4631
# {'tropical fruit', 'root vegetables'} => {'citrus fruit', 'other vegetables'}    0.0045      0.2126    7.3610
# {'root vegetables', 'citrus fruit'} => {'tropical fruit', 'other vegetables'}    0.0045      0.2529    7.0454
# {'processed cheese'} => {'white bread'}     0.0042      0.2515    5.9754
# {'tropical fruit', 'whipped/sour cream'} => {'yogurt', 'whole milk'}    0.0044      0.3162    5.6435
# {'tropical fruit', 'root vegetables'} => {'other vegetables', 'yogurt'}    0.0050      0.2367    5.4522
# {'liquor'} => {'bottled beer'}              0.0047      0.4220    5.2406
# {'herbs'} => {'root vegetables', 'whole milk'}    0.0042      0.2562    5.2395
# {'root vegetables', 'yogurt'} => {'tropical fruit', 'whole milk'}    0.0057      0.2205    5.2124
# {'berries', 'whole milk'} => {'whipped/sour cream'}    0.0043      0.3621    5.0510
# {'whipped/sour cream', 'yogurt'} => {'tropical fruit', 'whole milk'}    0.0044      0.2108    4.9833
# {'herbs', 'whole milk'} => {'root vegetables'}    0.0042      0.5395    4.9494
# {'tropical fruit', 'root vegetables'} => {'yogurt', 'whole milk'}    0.0057      0.2705    4.8288
# {'tropical fruit', 'citrus fruit'} => {'root vegetables', 'other vegetables'}    0.0045      0.2245    4.7379
# {'pip fruit', 'root vegetables'} => {'other vegetables', 'whole milk'}    0.0055      0.3529    4.7163
# {'tropical fruit', 'citrus fruit', 'other vegetables'} => {'root vegetables'}    0.0045      0.4944    4.5357
# {'tropical fruit', 'root vegetables'} => {'other vegetables', 'whole milk'}    0.0070      0.3333    4.4543
# {'tropical fruit', 'root vegetables', 'other vegetables'} => {'citrus fruit'}    0.0045      0.3636    4.3936
# {'root vegetables', 'citrus fruit'} => {'other vegetables', 'whole milk'}    0.0058      0.3276    4.3775
# {'tropical fruit', 'whipped/sour cream'} => {'other vegetables', 'whole milk'}    0.0045      0.3235    4.3232
# {'butter', 'root vegetables'} => {'other vegetables', 'whole milk'}    0.0042      0.3228    4.3140
# {'fruit/vegetable juice', 'other vegetables'} => {'yogurt', 'whole milk'}    0.0051      0.2415    4.3114
# {'pip fruit', 'other vegetables'} => {'root vegetables', 'whole milk'}    0.0055      0.2101    4.2963
# {'root vegetables', 'domestic eggs'} => {'other vegetables', 'whole milk'}    0.0046      0.3191    4.2647
# {'butter', 'other vegetables'} => {'root vegetables', 'whole milk'}    0.0042      0.2081    4.2555
# {'other vegetables', 'domestic eggs'} => {'root vegetables', 'whole milk'}    0.0046      0.2055    4.2014
# {'yogurt', 'whipped/sour cream'} => {'curd'}    0.0046      0.2206    4.1402
# {'root vegetables', 'citrus fruit', 'other vegetables'} => {'tropical fruit'}    0.0045      0.4314    4.1110
# {'citrus fruit', 'other vegetables'} => {'root vegetables', 'whole milk'}    0.0058      0.2007    4.1038
# {'other vegetables', 'citrus fruit', 'whole milk'} => {'root vegetables'}    0.0058      0.4453    4.0855
# {'root vegetables', 'tropical fruit', 'citrus fruit'} => {'other vegetables'}    0.0045      0.7857    4.0607
# {'root vegetables', 'whipped/sour cream'} => {'other vegetables', 'whole milk'}    0.0052      0.3036    4.0566
# {'root vegetables', 'yogurt'} => {'other vegetables', 'whole milk'}    0.0078      0.3031    4.0509
# {'butter', 'other vegetables'} => {'whipped/sour cream'}    0.0058      0.2893    4.0364
# {'yogurt', 'tropical fruit', 'whole milk'} => {'whipped/sour cream'}    0.0044      0.2886    4.0259
# {'butter', 'yogurt'} => {'other vegetables', 'whole milk'}    0.0044      0.2986    3.9903
# {'herbs'} => {'root vegetables'}            0.0070      0.4312    3.9565
# {'whipped/sour cream', 'tropical fruit', 'whole milk'} => {'yogurt'}    0.0044      0.5513    3.9518
# {'rolls/buns', 'root vegetables'} => {'beef'}    0.0050      0.2050    3.9077
# {'butter', 'other vegetables'} => {'yogurt', 'whole milk'}    0.0044      0.2183    3.8961
# {'pip fruit', 'citrus fruit'} => {'tropical fruit'}    0.0056      0.4044    3.8541
# {'yogurt', 'whipped/sour cream', 'whole milk'} => {'tropical fruit'}    0.0044      0.4019    3.8298
# {'berries'} => {'whipped/sour cream'}       0.0090      0.2722    3.7969
# {'tropical fruit', 'other vegetables'} => {'yogurt', 'whole milk'}    0.0076      0.2125    3.7924
# {'pip fruit', 'yogurt'} => {'other vegetables', 'whole milk'}    0.0051      0.2825    3.7748
# {'tropical fruit', 'other vegetables', 'whole milk'} => {'root vegetables'}    0.0070      0.4107    3.7681
# {'whole milk', 'whipped/sour cream'} => {'butter'}    0.0067      0.2082    3.7572
# {'yogurt', 'root vegetables', 'whole milk'} => {'tropical fruit'}    0.0057      0.3916    3.7320
# {'other vegetables', 'pip fruit', 'whole milk'} => {'root vegetables'}    0.0055      0.4060    3.7250
# {'tropical fruit', 'other vegetables', 'yogurt'} => {'root vegetables'}    0.0050      0.4050    3.7153
# {'tropical fruit', 'citrus fruit'} => {'pip fruit'}    0.0056      0.2806    3.7094
# {'other vegetables', 'domestic eggs'} => {'butter'}    0.0046      0.2055    3.7081
# {'tropical fruit', 'other vegetables', 'whole milk'} => {'pip fruit'}    0.0048      0.2798    3.6982
# {'curd', 'yogurt'} => {'whipped/sour cream'}    0.0046      0.2647    3.6927
# {'curd', 'tropical fruit'} => {'yogurt'}    0.0053      0.5149    3.6906
# {'beef', 'other vegetables'} => {'root vegetables'}    0.0079      0.4021    3.6887
# {'other vegetables', 'root vegetables', 'yogurt'} => {'tropical fruit'}    0.0050      0.3858    3.6769
# {'onions', 'other vegetables'} => {'root vegetables'}    0.0057      0.4000    3.6698
# {'beef', 'other vegetables'} => {'pork'}    0.0042      0.2113    3.6658
# {'other vegetables', 'tropical fruit', 'whole milk'} => {'whipped/sour cream'}    0.0045      0.2619    3.6537
# {'other vegetables', 'citrus fruit', 'whole milk'} => {'tropical fruit'}    0.0050      0.3828    3.6482
# {'oil', 'whole milk'} => {'root vegetables'}    0.0045      0.3964    3.6367
# {'fruit/vegetable juice', 'yogurt'} => {'other vegetables', 'whole milk'}    0.0051      0.2717    3.6312
# {'onions', 'whole milk'} => {'root vegetables'}    0.0048      0.3950    3.6235
# {'other vegetables', 'whipped/sour cream'} => {'butter'}    0.0058      0.2007    3.6219
# {'whole milk', 'domestic eggs'} => {'butter'}    0.0060      0.2000    3.6092
# {'baking powder'} => {'whipped/sour cream'}    0.0046      0.2586    3.6079
# {'whipped/sour cream', 'yogurt'} => {'other vegetables', 'whole milk'}    0.0056      0.2696    3.6027
# {'butter', 'other vegetables'} => {'domestic eggs'}    0.0046      0.2284    3.6003
# {'beef', 'yogurt'} => {'root vegetables'}    0.0046      0.3913    3.5900
# {'curd', 'other vegetables'} => {'whipped/sour cream'}    0.0044      0.2544    3.5495
# {'tropical fruit', 'other vegetables', 'whole milk'} => {'citrus fruit'}    0.0050      0.2917    3.5240
# {'yogurt', 'other vegetables', 'whole milk'} => {'whipped/sour cream'}    0.0056      0.2511    3.5035
# {'tropical fruit', 'other vegetables'} => {'pip fruit'}    0.0095      0.2635    3.4826
# {'tropical fruit', 'yogurt'} => {'other vegetables', 'whole milk'}    0.0076      0.2604    3.4799
# {'other vegetables', 'fruit/vegetable juice', 'whole milk'} => {'yogurt'}    0.0051      0.4854    3.4798
# {'beef', 'whole milk'} => {'root vegetables'}    0.0080      0.3780    3.4679
# {'root vegetables', 'yogurt'} => {'whipped/sour cream'}    0.0064      0.2480    3.4601
# {'pip fruit', 'other vegetables'} => {'tropical fruit'}    0.0095      0.3619    3.4486
# {'yogurt', 'tropical fruit', 'whole milk'} => {'root vegetables'}    0.0057      0.3758    3.4481
# {'butter', 'whole milk'} => {'domestic eggs'}    0.0060      0.2177    3.4314
# {'other vegetables', 'whole milk', 'domestic eggs'} => {'root vegetables'}    0.0046      0.3719    3.4120
# {'rolls/buns', 'root vegetables'} => {'other vegetables', 'whole milk'}    0.0062      0.2552    3.4106
# {'tropical fruit', 'root vegetables', 'whole milk'} => {'yogurt'}    0.0057      0.4746    3.4019
# {'butter', 'whole milk'} => {'whipped/sour cream'}    0.0067      0.2435    3.3975
# {'pip fruit', 'yogurt'} => {'tropical fruit'}    0.0064      0.3559    3.3920
# {'margarine', 'whole milk'} => {'domestic eggs'}    0.0052      0.2143    3.3774
# {'other vegetables', 'pip fruit', 'whole milk'} => {'tropical fruit'}    0.0048      0.3534    3.3678
# {'beef', 'rolls/buns'} => {'root vegetables'}    0.0050      0.3657    3.3548
# {'herbs'} => {'whole milk', 'other vegetables'}    0.0041      0.2500    3.3407
# {'tropical fruit', 'citrus fruit'} => {'other vegetables', 'whole milk'}    0.0050      0.2500    3.3407
# {'butter', 'other vegetables', 'whole milk'} => {'root vegetables'}    0.0042      0.3628    3.3288
# {'other vegetables', 'rolls/buns', 'yogurt'} => {'root vegetables'}    0.0042      0.3628    3.3288
# {'tropical fruit', 'root vegetables'} => {'pip fruit'}    0.0053      0.2512    3.3207
# {'chicken', 'whole milk'} => {'whipped/sour cream'}    0.0042      0.2370    3.3062
# {'tropical fruit', 'pip fruit'} => {'citrus fruit'}    0.0056      0.2736    3.3061
# {'baking powder'} => {'whole milk', 'other vegetables'}    0.0044      0.2471    3.3023
# {'citrus fruit', 'other vegetables'} => {'root vegetables'}    0.0104      0.3592    3.2950
# {'butter', 'tropical fruit'} => {'yogurt'}    0.0046      0.4592    3.2916
# {'root vegetables', 'citrus fruit', 'whole milk'} => {'other vegetables'}    0.0058      0.6333    3.2732
# {'rolls/buns', 'shopping bags'} => {'sausage'}    0.0060      0.3073    3.2708
# {'tropical fruit', 'root vegetables'} => {'citrus fruit'}    0.0057      0.2705    3.2686
# {'other vegetables', 'yogurt'} => {'whipped/sour cream'}    0.0102      0.2342    3.2671
# {'yogurt', 'other vegetables', 'whole milk'} => {'tropical fruit'}    0.0076      0.3425    3.2637
# {'flour'} => {'whipped/sour cream'}         0.0041      0.2339    3.2632
# {'whole milk', 'other vegetables', 'whipped/sour cream'} => {'root vegetables'}    0.0052      0.3542    3.2493
# {'pip fruit', 'root vegetables'} => {'tropical fruit'}    0.0053      0.3399    3.2390
# {'yogurt', 'other vegetables', 'whole milk'} => {'root vegetables'}    0.0078      0.3516    3.2257
# {'tropical fruit', 'whipped/sour cream'} => {'yogurt'}    0.0062      0.4485    3.2152
# {'root vegetables', 'soda'} => {'other vegetables', 'whole milk'}    0.0045      0.2404    3.2129
# {'tropical fruit', 'other vegetables', 'whole milk'} => {'yogurt'}    0.0076      0.4464    3.2002
# {'tropical fruit', 'rolls/buns', 'whole milk'} => {'yogurt'}    0.0049      0.4444    3.1859
# {'other vegetables', 'domestic eggs'} => {'whipped/sour cream'}    0.0051      0.2283    3.1850
# {'other vegetables', 'rolls/buns', 'whole milk'} => {'root vegetables'}    0.0062      0.3466    3.1798
# {'pip fruit', 'root vegetables', 'whole milk'} => {'other vegetables'}    0.0055      0.6136    3.1714
# {'tropical fruit', 'root vegetables', 'yogurt'} => {'other vegetables'}    0.0050      0.6125    3.1655
# {'yogurt', 'other vegetables', 'whole milk'} => {'fruit/vegetable juice'}    0.0051      0.2283    3.1581
# {'red/blush wine'} => {'bottled beer'}      0.0049      0.2540    3.1538
# {'curd', 'whole milk'} => {'whipped/sour cream'}    0.0059      0.2257    3.1483
# {'frozen vegetables', 'other vegetables'} => {'root vegetables'}    0.0061      0.3429    3.1455
# {'tropical fruit', 'other vegetables'} => {'root vegetables'}    0.0123      0.3428    3.1448
# {'curd', 'whipped/sour cream'} => {'yogurt'}    0.0046      0.4369    3.1318
# {'other vegetables', 'root vegetables', 'whole milk'} => {'pip fruit'}    0.0055      0.2368    3.1308
# {'chicken', 'whole milk'} => {'root vegetables'}    0.0060      0.3410    3.1289
# {'tropical fruit', 'pip fruit'} => {'other vegetables', 'whole milk'}    0.0048      0.2338    3.1246
# {'pip fruit', 'whipped/sour cream'} => {'other vegetables'}    0.0056      0.6044    3.1236
# {'other vegetables', 'root vegetables', 'whole milk'} => {'whipped/sour cream'}    0.0052      0.2237    3.1205
# {'tropical fruit', 'margarine'} => {'yogurt'}    0.0041      0.4348    3.1167
# {'onions', 'root vegetables'} => {'other vegetables'}    0.0057      0.6022    3.1120
# {'curd', 'root vegetables'} => {'yogurt'}    0.0047      0.4299    3.0817
# {'root vegetables', 'cream cheese'} => {'other vegetables'}    0.0045      0.5946    3.0730
# {'yogurt', 'pastry'} => {'other vegetables', 'whole milk'}    0.0041      0.2299    3.0719
# {'root vegetables', 'citrus fruit'} => {'tropical fruit'}    0.0057      0.3218    3.0671
# {'pip fruit', 'rolls/buns'} => {'tropical fruit'}    0.0045      0.3212    3.0607
# {'sliced cheese'} => {'sausage'}            0.0070      0.2863    3.0474
# {'tropical fruit', 'other vegetables'} => {'citrus fruit'}    0.0090      0.2521    3.0462
# {'whole milk', 'sliced cheese'} => {'yogurt'}    0.0046      0.4245    3.0432
# {'tropical fruit', 'other vegetables'} => {'whipped/sour cream'}    0.0078      0.2181    3.0430
# {'beef'} => {'root vegetables'}             0.0174      0.3314    3.0404
# {'tropical fruit', 'whipped/sour cream'} => {'root vegetables'}    0.0046      0.3309    3.0357
# {'tropical fruit', 'root vegetables'} => {'whipped/sour cream'}    0.0046      0.2174    3.0327
# {'beef', 'tropical fruit'} => {'other vegetables'}    0.0045      0.5867    3.0320
# {'root vegetables', 'citrus fruit'} => {'other vegetables'}    0.0104      0.5862    3.0296
# {'butter', 'other vegetables'} => {'root vegetables'}    0.0066      0.3299    3.0271
# {'hygiene articles', 'whole milk'} => {'tropical fruit'}    0.0041      0.3175    3.0254
# {'chicken', 'yogurt'} => {'other vegetables'}    0.0049      0.5854    3.0253
# {'tropical fruit', 'root vegetables', 'whole milk'} => {'other vegetables'}    0.0070      0.5847    3.0221
# {'tropical fruit', 'root vegetables'} => {'other vegetables'}    0.0123      0.5845    3.0210
# {'other vegetables', 'root vegetables', 'whole milk'} => {'citrus fruit'}    0.0058      0.2500    3.0206
# {'yogurt', 'other vegetables', 'whole milk'} => {'pip fruit'}    0.0051      0.2283    3.0181
# {'other vegetables', 'domestic eggs'} => {'root vegetables'}    0.0073      0.3288    3.0163
# {'citrus fruit', 'whipped/sour cream'} => {'yogurt'}    0.0046      0.4206    3.0147
# {'root vegetables', 'yogurt'} => {'tropical fruit'}    0.0081      0.3150    3.0016
