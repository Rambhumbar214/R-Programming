# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

# Load dataset
url = "C:/Users/Admin/Desktop/Ram_Datamininig/Chapter6/customers.csv"
df = pd.read_csv(url)

# Assume dataset is numeric or process accordingly
df = df.select_dtypes(include=['float64', 'int64']).dropna()

# Scale features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df)

# Plot dendrogram
linked = linkage(data_scaled, method='ward')
plt.figure(figsize=(10, 7))
dendrogram(linked)
plt.title('Hierarchical Clustering Dendrogram')
plt.show()

# Agglomerative clustering with chosen clusters, e.g., 3
agglo = AgglomerativeClustering(n_clusters=3)
clusters = agglo.fit_predict(data_scaled)

df['Cluster'] = clusters
print(df['Cluster'].value_counts())
# Out:
# Cluster
# 1    74
# 0    74
# 2    52
# Name: count, dtype: int64
